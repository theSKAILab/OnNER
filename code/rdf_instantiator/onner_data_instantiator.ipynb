# %%
import xml.etree.ElementTree as ET
import re
import os
import spacy
import scispacy
from datetime import datetime

# %% [markdown]
# ### XML Reader

# %%
# LOADING XML AND CREATING ROOT

xml_file = 'D:\\Drive\\SISE\\CelloGraph\\Dev\\Data\\XML\\Rojas 2016 - Cellulose Chemistry And Properties - Chapter1.tei.xmlScitex.xml'
tree = ET.parse(xml_file)
root = tree.getroot()

# EXTRACTING METADATA (available data: title, publication_date and doi)

metadata = []

for elem in root:
    if elem.tag[29:] == 'teiHeader':
        for sub_elem1 in elem:
            if sub_elem1.tag[29:] == 'fileDesc':
                publication_info = {}
                for sub_elem2 in sub_elem1:
                    if sub_elem2.tag[29:] == 'titleStmt':
                        for sub_elem3 in sub_elem2:
                            if sub_elem3.tag[29:] == 'title':
                                publication_info['Title'] = sub_elem3.text
                    if sub_elem2.tag[29:] == 'publicationStmt':
                        for sub_elem3 in sub_elem2:
                            if sub_elem3.tag[29:] == 'date':
                                publication_info['Publication Date'] = sub_elem3.attrib['when']
                    if sub_elem2.tag[29:] == 'sourceDesc':
                        for sub_elem3 in sub_elem2:
                            if sub_elem3.tag[29:] == 'biblStruct':
                                for sub_elem4 in sub_elem3:
                                    if sub_elem4.tag[29:] == 'idno':
                                        publication_info['DOI'] = sub_elem4.text
                metadata.append(['0', 'Metadata', publication_info])
                                      
print(metadata)
# Out:
# [['0', 'Metadata', {'Title': 'Cellulose: Structure and Properties', 'Publication Date': '2015-09-10', 'DOI': '10.1007/12_2015_319'}]]

# %%
# EXTRACTING ABSTRACT AND NUMBERING PARAGRAPHS

abstract = []

for elem in root:
    if elem.tag[29:] == 'teiHeader':
        for sub_elem1 in elem:
            if sub_elem1.tag[29:] == 'profileDesc':
                for sub_elem2 in sub_elem1:
                    if sub_elem2.tag[29:] == 'abstract':
                        for sub_elem3 in sub_elem2:
                            if sub_elem3.tag[29:] == 'div':
                                list_of_paragraphs = {}
                                paragraph_number = 0
                                for sub_elem4 in sub_elem3:
                                    if sub_elem4.tag[29:] == 'p':
                                        paragraph_number += 1
                                        list_of_paragraphs[paragraph_number] = ET.tostring(sub_elem4, encoding='unicode')
                                abstract.append(['0', 'Abstract', list_of_paragraphs])
                                
print(abstract)
# Out:
# [['0', 'Abstract', {1: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">This work was aimed to evaluate the performance of two different surface modifications on cellulose nano-particles obtained from blue agave bagasse. Cellulose nanofibers were obtained from traditional mechanical methods, and cellulose nanocrystals were obtained via sulfuric acid hydrolysis. After cellulose extraction and size reduction, different composites were elaborated using poly(lactic acid) as matrix varying fiber concentrations and using cellulosic particles of diverse size and surface modification (3aminopropyl triethoxysilane silanized cellulose nanofibers and dodecanoyl chloride esterified cellulose nanocrystals). Non-cellulosic elimination and the effect of surface modifications were analyzed with infrared analysis, showing characteristic intensities for cellulosic species and new peaks for each modification (characteristic ester peak ∼1740 cm −1 , and amino peak ∼1550 cm −1 ) cellulose nanofibers and nanocrystals were observed with atom-force microscopy; crystallinity of nano-scale cellulose before and after modifications was obtained with X-ray diffraction to analyze the performance of the modifications. Composites were tested with stress-strain standard methods showing better mechanical properties when surface modifications were performed and the amount of filler was 0.5 wt% reaching an increase in strain to fracture of more than 20%.</ns0:p>'}]]

# %%
# EXTRACTING OTHER SECTIONS

# add logic: if a paragraph does not have any labeled term
# \ issue in RDF, see Koshkava 2014 paper

list_of_sections = []

for elem in root:
    if (elem.tag[29:] == 'text'):
        for sub_elem1 in elem:
            if (sub_elem1.tag[29:] == 'body'):
                for sub_elem2 in sub_elem1:
                    if sub_elem2.tag[29:] == 'div':
                        section_number = ''
                        section_name = ''
                        list_of_paragraphs = []
                        for sub_elem3 in sub_elem2:
                            if sub_elem3.tag[29:] == 'head':
                                if bool(sub_elem3.attrib):
                                    section_number = str(sub_elem3.attrib)
                                    if section_number[-3] == '.':
                                        section_number = section_number[7:-3]
                                    else:
                                        section_number = section_number[7:-2]
                                else:
                                    section_number = 'NO_SECTION_NUMBER'
                                section_name = sub_elem3.text
                            if sub_elem3.tag[29:] == 'p':
                                list_of_paragraphs.append(ET.tostring(sub_elem3, encoding='unicode'))
                        # commented logic skips NO_SECTION_NUMBER with no paragraphs, i.e., Table 1, Table 2, .....
                        # if section_number == 'NO_SECTION_NUMBER' and not bool(list_of_paragraphs):
                        if section_number == 'NO_SECTION_NUMBER':
                            pass
                        else:
                            list_of_sections.append([section_number, section_name, list_of_paragraphs])

print(list_of_sections)
# Out:
# [['1', 'Introduction', ['<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources <ns0:ref type="bibr" target="#b0">[1]</ns0:ref>. In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems <ns0:ref type="bibr" target="#b1">[2]</ns0:ref>. Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) <ns0:ref type="bibr" target="#b2">[3]</ns0:ref>.</ns0:p>', '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" <ns0:ref type="bibr" target="#b3">[4]</ns0:ref>. Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp <ns0:ref type="bibr" target="#b4">[5,</ns0:ref><ns0:ref type="bibr" target="#b5">6]</ns0:ref>.</ns0:p>', '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own research in the field of chemical modification of cellulose by advanced organic chemistry.</ns0:p>']], ['2', 'Sources of Cellulose', ['<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is distributed throughout nature in plants, animals, algae, fungi, and minerals (Fig. <ns0:ref type="figure" target="#fig_0">1</ns0:ref>). However, the major source of cellulose is plant fiber. Cellulose contributes approximately 40% to the carbon fraction in plants, serving as structuring element within the complex architecture of their cell walls. Cellulose can occur in pure form in plants but it is usually accompanied by hemicelluloses, lignins, and comparably small amounts of extractives. Wood contains about 40-50 wt% cellulose. Comparable amounts can be found in bagasse <ns0:ref type="bibr">(35-45 wt%)</ns0:ref>, bamboo <ns0:ref type="bibr">(40-55 wt%)</ns0:ref>, straw (40-50 wt%), and even higher in flax (70-80 wt%), hemp <ns0:ref type="bibr">(75-80 wt%)</ns0:ref>, jute <ns0:ref type="bibr">(60-65 wt%)</ns0:ref>, kapok <ns0:ref type="bibr">(70-75 wt%)</ns0:ref>, and ramie (70-75 wt %). Cotton is a fairly pure cellulose source, containing more than 90 wt% <ns0:ref type="bibr" target="#b7">[8]</ns0:ref>. An impressive amount of cellulose is produced each year, not only in wood fiber from trees (ca. 1,750,000 kt world production) but also in annual plants such as bamboo (10,000 kt), cotton linter ...

# %%
# NUMBERING PARAGRAPHS OF SECTIONS 
# paragraphs are sequentially added in a dictionary
# dictionary is added with each respective record as a 4th element

for section in list_of_sections:
    list_of_paragraphs = {}
    for paragraph_number, paragraph_text in enumerate(section[2], start=1):
        list_of_paragraphs[paragraph_number] = paragraph_text
    section.append(list_of_paragraphs)
    
print(list_of_sections)
# Out:
# [['1', 'Introduction', ['<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources <ns0:ref type="bibr" target="#b0">[1]</ns0:ref>. In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems <ns0:ref type="bibr" target="#b1">[2]</ns0:ref>. Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) <ns0:ref type="bibr" target="#b2">[3]</ns0:ref>.</ns0:p>', '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" <ns0:ref type="bibr" target="#b3">[4]</ns0:ref>. Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp <ns0:ref type="bibr" target="#b4">[5,</ns0:ref><ns0:ref type="bibr" target="#b5">6]</ns0:ref>.</ns0:p>', '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own research in the field of chemical modification of cellulose by advanced organic chemistry.</ns0:p>'], {1: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources <ns0:ref type="bibr" target="#b0">[1]</ns0:ref>. In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems <ns0:ref type="bibr" target="#b1">[2]</ns0:ref>. Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) <ns0:ref type="bibr" target="#b2">[3]</ns0:ref>.</ns0:p>', 2: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance afte ...

# %%
# DELETING THE 3RD ELEMENT FROM EACH RECORD

for section in list_of_sections:
    section.remove(section[2])
    
print(list_of_sections)
# Out:
# [['1', 'Introduction', {1: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources <ns0:ref type="bibr" target="#b0">[1]</ns0:ref>. In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems <ns0:ref type="bibr" target="#b1">[2]</ns0:ref>. Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) <ns0:ref type="bibr" target="#b2">[3]</ns0:ref>.</ns0:p>', 2: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" <ns0:ref type="bibr" target="#b3">[4]</ns0:ref>. Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp <ns0:ref type="bibr" target="#b4">[5,</ns0:ref><ns0:ref type="bibr" target="#b5">6]</ns0:ref>.</ns0:p>', 3: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own research in the field of chemical modification of cellulose by advanced organic chemistry.</ns0:p>'}], ['2', 'Sources of Cellulose', {1: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is distributed throughout nature in plants, animals, algae, fungi, and minerals (Fig. <ns0:ref type="figure" target="#fig_0">1</ns0:ref>). However, the major source of cellulose is plant fiber. Cellulose contributes approximately 40% to the carbon fraction in plants, serving as structuring element within the complex architecture of their cell walls. Cellulose can occur in pure form in plants but it is usually accompanied by hemicelluloses, lignins, and comparably small amounts of extractives. Wood contains about 40-50 wt% cellulose. Comparable amounts can be found in bagasse <ns0:ref type="bibr">(35-45 wt%)</ns0:ref>, bamboo <ns0:ref type="bibr">(40-55 wt%)</ns0:ref>, straw (40-50 wt%), and even higher in flax (70-80 wt%), hemp <ns0:ref type="bibr">(75-80 wt%)</ns0:ref>, jute <ns0:ref type="bibr">(60-65 wt%)</ns0:ref>, kapok <ns0:ref type="bibr">(70-75 wt%)</ns0:ref>, and ramie (70-75 wt %). Cotton is a fairly pure cellulose source, containing more than 90 wt% <ns0:ref type="bibr" target="#b7">[8]</ns0:ref>. An impressive amount of cellulose is produced each year, not only in wood fiber from trees (ca. 1,750,000 kt world production) but also in annual plants such as bamboo (10,000 kt), c ...

# %%
# MERGING ABSTRACT WITH OTHER SECTIONS

document = abstract + list_of_sections
print(document)
# Out:
# [['0', 'Abstract', {1: 'This work was aimed to evaluate the performance of two different surface modifications on cellulose nano-particles obtained from blue agave bagasse. Cellulose nanofibers were obtained from traditional mechanical methods, and cellulose nanocrystals were obtained via sulfuric acid hydrolysis. After cellulose extraction and size reduction, different composites were elaborated using poly(lactic acid) as matrix varying fiber concentrations and using cellulosic particles of diverse size and surface modification (3aminopropyl triethoxysilane silanized cellulose nanofibers and dodecanoyl chloride esterified cellulose nanocrystals). Non-cellulosic elimination and the effect of surface modifications were analyzed with infrared analysis, showing characteristic intensities for cellulosic species and new peaks for each modification (characteristic ester peak ∼1740 cm −1 , and amino peak ∼1550 cm −1 ) cellulose nanofibers and nanocrystals were observed with atom-force microscopy; crystallinity of nano-scale cellulose before and after modifications was obtained with X-ray diffraction to analyze the performance of the modifications. Composites were tested with stress-strain standard methods showing better mechanical properties when surface modifications were performed and the amount of filler was 0.5 wt% reaching an increase in strain to fracture of more than 20%.'}], ['1', 'Introduction', {1: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources <ns0:ref type="bibr" target="#b0">[1]</ns0:ref>. In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems <ns0:ref type="bibr" target="#b1">[2]</ns0:ref>. Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) <ns0:ref type="bibr" target="#b2">[3]</ns0:ref>.</ns0:p>', 2: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" <ns0:ref type="bibr" target="#b3">[4]</ns0:ref>. Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp <ns0:ref type="bibr" target="#b4">[5,</ns0:ref><ns0:ref type="bibr" target="#b5">6]</ns0:ref>.</ns0:p>', 3: '<ns0:p xmlns:ns0="http://www.tei-c.org/ns/1.0">The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own res ...

# %%
# PREPROCESSING TEXT

starting_p_tag_pattern = r'<ns0:p[^>]+>'
ending_p_tag_pattern = '</ns0:p>'
starting_ref_tag_pattern = r'<ns0:ref[^>]+>'
ending_ref_tag_pattern = '</ns0:ref>'
ref_pattern = r'<ref>.*?</ref>'          # temporary for removing ref tag

for record in document:
    for paragraph_number, paragraph_text in record[2].items():
        text = paragraph_text
        text = re.sub(starting_p_tag_pattern, '', text)
        text = re.sub(ending_p_tag_pattern, '', text)
        text = re.sub(starting_ref_tag_pattern, '<ref>', text)
        text = re.sub(ending_ref_tag_pattern, '</ref>', text)
        text = re.sub(ref_pattern, '', text)
        record[2][paragraph_number] = text
        
print(document)
# Out:
# [['0', 'Abstract', {1: 'This work was aimed to evaluate the performance of two different surface modifications on cellulose nano-particles obtained from blue agave bagasse. Cellulose nanofibers were obtained from traditional mechanical methods, and cellulose nanocrystals were obtained via sulfuric acid hydrolysis. After cellulose extraction and size reduction, different composites were elaborated using poly(lactic acid) as matrix varying fiber concentrations and using cellulosic particles of diverse size and surface modification (3aminopropyl triethoxysilane silanized cellulose nanofibers and dodecanoyl chloride esterified cellulose nanocrystals). Non-cellulosic elimination and the effect of surface modifications were analyzed with infrared analysis, showing characteristic intensities for cellulosic species and new peaks for each modification (characteristic ester peak ∼1740 cm −1 , and amino peak ∼1550 cm −1 ) cellulose nanofibers and nanocrystals were observed with atom-force microscopy; crystallinity of nano-scale cellulose before and after modifications was obtained with X-ray diffraction to analyze the performance of the modifications. Composites were tested with stress-strain standard methods showing better mechanical properties when surface modifications were performed and the amount of filler was 0.5 wt% reaching an increase in strain to fracture of more than 20%.'}], ['1', 'Introduction', {1: 'Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources . In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems . Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) .', 2: 'The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" . Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp .', 3: 'The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own research in the field of chemical modification of cellulose by advanced organic chemistry.'}], ['2', 'Sources of Cellulose', {1: 'Cellulose is distributed throughout nature in plants, animals, algae, fungi, and minerals (Fig. ). However, the major source of cellulose is plant fiber. Cellulose contributes approximately 40% to the carbon fraction in plants, serving as structuring element within the complex architecture of their cell walls. ...

# %%
# MERGING METADATA WITH OTHER DOCUMENT PARTS

document = metadata + document
print(document)
# Out:
# [['0', 'Metadata', {'Title': 'Cellulose: Structure and Properties', 'Publication Date': '2015-09-10', 'DOI': '10.1007/12_2015_319'}], ['0', 'Abstract', {1: 'This work was aimed to evaluate the performance of two different surface modifications on cellulose nano-particles obtained from blue agave bagasse. Cellulose nanofibers were obtained from traditional mechanical methods, and cellulose nanocrystals were obtained via sulfuric acid hydrolysis. After cellulose extraction and size reduction, different composites were elaborated using poly(lactic acid) as matrix varying fiber concentrations and using cellulosic particles of diverse size and surface modification (3aminopropyl triethoxysilane silanized cellulose nanofibers and dodecanoyl chloride esterified cellulose nanocrystals). Non-cellulosic elimination and the effect of surface modifications were analyzed with infrared analysis, showing characteristic intensities for cellulosic species and new peaks for each modification (characteristic ester peak ∼1740 cm −1 , and amino peak ∼1550 cm −1 ) cellulose nanofibers and nanocrystals were observed with atom-force microscopy; crystallinity of nano-scale cellulose before and after modifications was obtained with X-ray diffraction to analyze the performance of the modifications. Composites were tested with stress-strain standard methods showing better mechanical properties when surface modifications were performed and the amount of filler was 0.5 wt% reaching an increase in strain to fracture of more than 20%.'}], ['1', 'Introduction', {1: 'Cellulose is the most abundant natural polymer in the biosphere, with a global production (and decomposition) of ~1.5 Â 10 <super>12</super> tons per year, comparable to the planetary reserves of the main fossil and mineral sources . In addition to the long-standing scientific interest in cellulose, the use of cellulose as renewable and biodegradable raw material in various applications is a proposed solution to the recent industrial challenge to successfully meet environmental and recycling problems . Versatile structuring of cellulose by various routes of modification, including both physical and chemical methods, has enabled its use in a variety of applications (e.g., fillers, building and coating materials, laminates, papers, textiles, optical films, sorption media, viscosity regulators, and even advanced functional materials) .', 2: 'The earliest systematic efforts that lead to the discovery of cellulose began in 1837 with the work of the French chemist Anselme Payen, who showed that various plant materials yielded a fibrous substance after purification with acid-ammonia treatment and extraction with water, alcohol, and ether. The French Academy finally named the resulting carbohydrate "cellulose" . Nowadays, there are various processes used to isolate cellulose, for example, the alkaline, bisulfite, and sulfate (kraft-) processes, in combination with thermal and mechanical treatments. The different processes result in varying fiber strengths of the pulp .', 3: 'The aim of this review is to discuss the different structural levels of cellulose and to describe important properties that result from this unique structure. Moreover, advanced micro-and nanostructural materials based on cellulose obtained by physical and hydrolytic treatments (top-down approaches) as well as the bottomup elaboration of nanostructures by electrospinning and nanoprecipitation are highlighted. Finally, one of the most important paths for the design of highly engineered products, namely chemical modification of cellulose (particularly under homogeneous reactions conditions), is summarized with consideration of our own research in the field of chemical modification of cellulose by advanced organic chemistry.'}], ['2', 'Sources of Cellulose', {1: 'Cellulose is distributed throughout nature in plants, animals, algae, fungi, and minerals (Fig. ). However, the major source of cellulose is plant fiber. Cellulose contributes ap ...

# %% [markdown]
# ### XRI (XML-to-RDF-Intermediate) to RDF

# %%
# LOADING THE NER MODEL

try:
    model_path = 'C:/Users/umayer/_dev/experiment'
    model_name = 'MULTI_LABEL_CELLULOSIC_MODEL_ACC/model-best'
    nlp = spacy.load(f'{model_path}/{model_name}')
except OSError:
    print('ERROR: Model Not Found!')
else:
    print('Model loaded successfully.')
# Out:
# Model loaded successfully.

# %%
# WRITING RDF TRIPLES FOR DOCUMENT

# DECLARING VARIABLE
labels_in_doc = []

# DECLARING LABELING SCHEMA
# labeling_schema = ['ENTITY', 
#                    'CHEMICAL_ENTITY', 
#                    'MATERIAL_ENTITY', 
#                    'STRUCTURE_ENTITY',
#                    'APPLICATION',
#                    'PROCESS',
#                    'PROPERTY',
#                    'EQUIPMENT',
#                    'RELATIONSHIP',
#                    'MEASUREMENT', 
#                    'ABBREVIATION']

labeling_schema = ['CHEMICAL', 
                   'MATERIAL', 
                   'MATERIAL_STRUCTURE',
                   'APPLICATION',
                   'PROCESS_OR_TECHNIQUE',
                   'PROPERTY',
                   'MEASUREMENT', 
                   'ABBREVIATION']

# GETTING DOI
try:
    doi = document[0][2]['DOI']
    doi = doi.replace('/', '_')
except NameError:
    print('ERROR: Document object is not defined!')

# PRINTING PREFIXES
print("@prefix onner: <http://spatialai.org/cellograph/ontology/onner/v2.0#> .")
print("@prefix data: <http://spatialai.org/cellograph/ontology/onner/v2.0/data#> .")
print("@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .")
print("@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .")
print("@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .")
print("@prefix owl: <http://www.w3.org/2002/07/owl#> .")
print()

try:
    for record in document:

        # METADATA
        if record[1] == 'Metadata':

            # PRINTING METADATA
            print(f"data:Publication_{doi} rdf:type onner:ScholarlyPublication ;")
            print(f"onner:publicationTitle '{record[2]['Title']}'^^xsd:string ;")
            print(f"onner:doi '{record[2]['DOI']}'^^xsd:string ;")
            print(f"onner:publicationDate '{record[2]['Publication Date']}'^^xsd:date .")
            print()

        # ABSTRACT AND IT'S DOCUMENT PARTS
        elif record[1] == 'Abstract':
            index = document.index(record) + 1
            next_section = document[index][0]
            paragraph_ids = []

            # CREATING PARAGRAPH ID FOR ABSTRACT'S PARAGRAPH 
            for paragraph_number, _ in record[2].items():
                paragraph_id = doi + '_A' + '-' + str(paragraph_number)
                paragraph_ids.append('data:'+paragraph_id)

            paragraph_ids_joined = ', '.join(paragraph_ids)

            # PRINTING ABSTRACT AND IT'S PARAGRAPH IDs 
            print(f"data:{doi}_A rdf:type onner:Abstract ;")
            print(f"onner:nextDocumentPart {paragraph_ids[0]} ;")    # NEXT DOC PART AFTER ABSTRACT
            print(f"onner:directlyContainsDocumentPart {paragraph_ids_joined} .")
            print()

            # PARAGRAPHS AND IT'S DOCUMENT PARTS
            for paragraph_number, paragraph_text in record[2].items():
                labeled_term_info_list = []
                labeled_term_number = 1

                # replacing ' with \' in text
                if "'" in paragraph_text:
                    paragraph_text = paragraph_text.replace("'", r"\'")

                # creating doc object
                doc = nlp(paragraph_text)

                for ent in doc.ents:
                    current_dateTime = str(datetime.now())[:-7]    # RECHECK THE APPROPRIATE PLACEMENT
                    labeled_term_id = doi + '_A' + '-' + str(paragraph_number) + '-' + str(labeled_term_number)
                    labeled_term = ent.text
                    label = ent.label_
                    offset = ent.start_char
                    length = ent.end_char - ent.start_char
                    labeled_term_info = [labeled_term_id, labeled_term, label, offset, length, current_dateTime]
                    labeled_term_info_list.append(labeled_term_info)
                    labeled_term_number += 1

                labeled_term_ids = ['data:'+i[0] for i in labeled_term_info_list]
                labeled_term_ids_joined = ', '.join(labeled_term_ids)

                # PRINTING PARAGRAPHS AND IT'S LABELED TERM IDs 
                print(f"data:{doi}_A-{paragraph_number} rdf:type onner:Paragraph ;")
                print(f"onner:positionInParentDocumentPart '{paragraph_number}'^^xsd:nonNegativeInteger ;")

                if paragraph_number == len(paragraph_ids):
                    print(f"onner:nextDocumentPart data:{doi}_{next_section} ;")
                else:
                    print(f"onner:nextDocumentPart data:{doi}_A-{paragraph_number+1} ;")

                print(f"onner:paragraphText '{paragraph_text}'^^xsd:string ;")
                print(f"onner:directlyContainsLabeledTerm {labeled_term_ids_joined} .")
                print()

                # LABELED TERMS
                for info in labeled_term_info_list:
                    # PRINTING LABELED TERMS
                    print(f"data:{info[0]} rdf:type onner:LabeledTerm ;")    # DEAL WITH ATOMIC / COMPOUND
                    print(f"onner:labeledTermText '{info[1]}'^^xsd:string ;")
                    print(f"onner:offset '{info[3]}'^^xsd:nonNegativeInteger ;")
                    print(f"onner:length '{info[4]}'^^xsd:nonNegativeInteger ;")
                    print(f"onner:labeledTermDirectlyContainedBy data:{doi}_A-{paragraph_number} ;")
                    print(f"onner:hasLabeledTermStatus data:Candidate_{info[0]} .")
                    print()

                    # PRINTING LABELED TERMS STATUS
                    print(f"data:Candidate_{info[0]} rdf:type onner:CandidateStatus ;")
                    print(f"onner:statusAssignmentDate '{info[5]}'^^xsd:dateTime ;")
                    print(f"onner:statusAssignedBy data:Cellulosic_NER_Model ;")

                    try:
                        if not bool(labeling_schema):
                            raise Exception('Labeling schema is empty!')
                            
                        label_number_in_schema = labeling_schema.index(info[2]) + 1
                    except Exception as e:
                        print(f'ERROR: {e}')
                    else:
                        print(f"onner:hasLabeledTermLabel data:Label_{label_number_in_schema} .")

                    # adding lebels and their position in the schema
                    if [label_number_in_schema, info[2]] not in labels_in_doc:
                        labels_in_doc.append([label_number_in_schema, info[2]])
                    print()
                    
            print('#========================= SECTION DIVIDER =========================#')
            print()

        # SECTION AND IT'S DOCUMENT PARTS
        else:
            section_number = record[0]
            section_name = record[1]
            index = document.index(record) + 1
            paragraph_ids = []

            if index == len(document):
                next_section = 'EndOfDocument'
            else:
                next_section = document[index][0]
            
            # EMPTY SECTION CHECK (N0 PARAGRAPHS BETWEEN A SECTION AND ITS IMMEDIATE SUBSECTION)
            if not bool(record[2]):
                section_ids = []

                for record in document:
                    pattern = rf'^{section_number}\.[^.]+$'
                    if re.search(pattern, record[0]):
                        section_id = doi + '_' + str(record[0])
                        section_ids.append('data:'+section_id)
                
                section_ids_joined = ', '.join(section_ids)
                
                print(f"data:{doi}_{section_number} rdf:type onner:Section ;")
                print(f"onner:sectionTitle '{section_number}'^^xsd:string ;")
                print(f"onner:sectionNumber '{section_name}'^^xsd:string ;")
                print(f"onner:nextDocumentPart data:{doi}_{next_section} ;")
                print(f"onner:directlyContainsDocumentPart {section_ids_joined} .")
                
                print()
                print('#========================= SECTION DIVIDER =========================#')
                print()
            
            # NON-EMPTY SECTION CHECK (PARAGRAPHS EXIST BETWEEN A SECTION AND ITS IMMEDIATE SUBSECTION)
            else:
                
                # CREATING PARAGRAPH ID FOR SECTION'S PARAGRAPH 
                for paragraph_number, _ in record[2].items():
                    paragraph_id = doi + '_' + str(section_number) + '-' + str(paragraph_number)
                    paragraph_ids.append('data:'+paragraph_id)

                paragraph_ids_joined = ', '.join(paragraph_ids)

                # PRINTING SECTION AND IT'S PARAGRAPH IDs 
                print(f"data:{doi}_{section_number} rdf:type onner:Section ;")
                print(f"onner:sectionTitle '{record[1]}'^^xsd:string ;")
                print(f"onner:sectionNumber '{record[0]}'^^xsd:string ;")
                print(f"onner:nextDocumentPart {paragraph_ids[0]} ;")    # NEXT DOC PART AFTER SECTION
                print(f"onner:directlyContainsDocumentPart {paragraph_ids_joined} .")
                print()

                # PARAGRAPHS AND IT'S DOCUMENT PARTS
                for paragraph_number, paragraph_text in record[2].items():
                    labeled_term_info_list = []
                    labeled_term_sequence = 1

                    # replacing ' with \' in text
                    if "'" in paragraph_text:
                        paragraph_text = paragraph_text.replace("'", r"\'")

                    # creating doc object
                    doc = nlp(paragraph_text)

                    for ent in doc.ents:
                        current_dateTime = str(datetime.now())[:-7]    # RECHECK THE APPROPRIATE PLACEMENT
                        labeled_term_id = doi + '_' + str(section_number) + '-' + str(paragraph_number) + '-' + str(labeled_term_sequence)
                        labeled_term = ent.text
                        label = ent.label_
                        offset = ent.start_char
                        length = ent.end_char - ent.start_char
                        labeled_term_info = [labeled_term_id, labeled_term, label, offset, length, current_dateTime]
                        labeled_term_info_list.append(labeled_term_info)
                        labeled_term_sequence += 1

                    labeled_term_ids = ['data:'+i[0] for i in labeled_term_info_list]
                    labeled_term_ids_joined = ', '.join(labeled_term_ids)

                    # PRINTING PARAGRAPHS AND IT'S LABELED TERM IDs 
                    print(f"data:{doi}_{section_number}-{paragraph_number} rdf:type onner:Paragraph ;")
                    print(f"onner:positionInParentDocumentPart '{paragraph_number}'^^xsd:nonNegativeInteger ;")

                    if paragraph_number == len(paragraph_ids):
                        print(f"onner:nextDocumentPart data:{doi}_{next_section} ;")
                    else:
                        print(f"onner:nextDocumentPart data:{doi}_{section_number}-{paragraph_number+1} ;")

                    print(f"onner:paragraphText '{paragraph_text}'^^xsd:string ;")
                    print(f"onner:directlyContainsLabeledTerm {labeled_term_ids_joined} .")
                    print()

                    # LABELED TERMS
                    for info in labeled_term_info_list:
                        # PRINTING LABELED TERMS
                        print(f"data:{info[0]} rdf:type onner:LabeledTerm ;")    # DEAL WITH ATOMIC / COMPOUND
                        print(f"onner:labeledTermText '{info[1]}'^^xsd:string ;")
                        print(f"onner:offset '{info[3]}'^^xsd:nonNegativeInteger ;")
                        print(f"onner:length '{info[4]}'^^xsd:nonNegativeInteger ;")
                        print(f"onner:labeledTermDirectlyContainedBy data:{doi}_{section_number}-{paragraph_number} ;")
                        print(f"onner:hasLabeledTermStatus data:Candidate_{info[0]} .")
                        print()

                        # PRINTING LABELED TERMS STATUS
                        print(f"data:Candidate_{info[0]} rdf:type onner:CandidateStatus ;")
                        print(f"onner:statusAssignmentDate '{info[5]}'^^xsd:dateTime ;")
                        print(f"onner:statusAssignedBy data:Cellulosic_NER_Model ;")

                        try:
                            if not bool(labeling_schema):
                                raise Exception('Labeling schema is empty!')

                            label_number_in_schema = labeling_schema.index(info[2]) + 1
                        except Exception as e:
                            print(f'ERROR: {e}')
                        else:
                            print(f"onner:hasLabeledTermLabel data:Label_{label_number_in_schema} .")

                        # adding lebels and their position in the schema
                        if [label_number_in_schema, info[2]] not in labels_in_doc:
                            labels_in_doc.append([label_number_in_schema, info[2]])

                        print()

                print('#========================= SECTION DIVIDER =========================#')
                print()

except NameError:
    print('ERROR: Document object is not defined!')

try:
    if not bool(labels_in_doc):
        raise Exception('List of labels found in document is empty!')
        
    for label in labels_in_doc:
        print(f"data:Label_{label[0]} rdf:type onner:Label ;")
        print(f"onner:fromLabelingSchema data:Dev_Schema ;")
        print(f"onner:labelText '{label[1]}'^^xsd:string .")
        print()       
except Exception as e:
    print(f'ERROR: {e}')

print(f"data:Dev_Schema rdf:type onner:LabelingSchema ;")
print(f"onner:schemaName 'CelloGraph'^^xsd:string .")
print()
            
print(f"data:Cellulosic_NER_Model rdf:type onner:NER_System ;")    # if/else required to identify system and human
print(f"onner:systemVersion '1.0'^^xsd:string .")
print()

print(f"data:{doi}_EndOfDocument rdf:type onner:EndOfDocument .")
# Out:
# @prefix onner: <http://spatialai.org/cellograph/ontology/onner/v2.0#> .
# @prefix data: <http://spatialai.org/cellograph/ontology/onner/v2.0/data#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
#
# data:Publication_10.1016_j.indcrop.2015.03.075 rdf:type onner:ScholarlyPublication ;
# onner:publicationTitle 'Industrial Crops and Products'^^xsd:string ;
# onner:doi '10.1016/j.indcrop.2015.03.075'^^xsd:string ;
# onner:publicationDate '2015-04-08'^^xsd:date .
#
# data:10.1016_j.indcrop.2015.03.075_A rdf:type onner:Abstract ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:directlyContainsDocumentPart data:10.1016_j.indcrop.2015.03.075_A-1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1 rdf:type onner:Paragraph ;
# onner:positionInParentDocumentPart '1'^^xsd:nonNegativeInteger ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_1 ;
# onner:paragraphText 'This work was aimed to evaluate the performance of two different surface modifications on cellulose nano-particles obtained from blue agave bagasse. Cellulose nanofibers were obtained from traditional mechanical methods, and cellulose nanocrystals were obtained via sulfuric acid hydrolysis. After cellulose extraction and size reduction, different composites were elaborated using poly(lactic acid) as matrix varying fiber concentrations and using cellulosic particles of diverse size and surface modification (3aminopropyl triethoxysilane silanized cellulose nanofibers and dodecanoyl chloride esterified cellulose nanocrystals). Non-cellulosic elimination and the effect of surface modifications were analyzed with infrared analysis, showing characteristic intensities for cellulosic species and new peaks for each modification (characteristic ester peak ∼1740 cm −1 , and amino peak ∼1550 cm −1 ) cellulose nanofibers and nanocrystals were observed with atom-force microscopy; crystallinity of nano-scale cellulose before and after modifications was obtained with X-ray diffraction to analyze the performance of the modifications. Composites were tested with stress-strain standard methods showing better mechanical properties when surface modifications were performed and the amount of filler was 0.5 wt% reaching an increase in strain to fracture of more than 20%.'^^xsd:string ;
# onner:directlyContainsLabeledTerm data:10.1016_j.indcrop.2015.03.075_A-1-1, data:10.1016_j.indcrop.2015.03.075_A-1-2, data:10.1016_j.indcrop.2015.03.075_A-1-3, data:10.1016_j.indcrop.2015.03.075_A-1-4, data:10.1016_j.indcrop.2015.03.075_A-1-5, data:10.1016_j.indcrop.2015.03.075_A-1-6, data:10.1016_j.indcrop.2015.03.075_A-1-7, data:10.1016_j.indcrop.2015.03.075_A-1-8, data:10.1016_j.indcrop.2015.03.075_A-1-9, data:10.1016_j.indcrop.2015.03.075_A-1-10, data:10.1016_j.indcrop.2015.03.075_A-1-11, data:10.1016_j.indcrop.2015.03.075_A-1-12, data:10.1016_j.indcrop.2015.03.075_A-1-13, data:10.1016_j.indcrop.2015.03.075_A-1-14, data:10.1016_j.indcrop.2015.03.075_A-1-15, data:10.1016_j.indcrop.2015.03.075_A-1-16, data:10.1016_j.indcrop.2015.03.075_A-1-17, data:10.1016_j.indcrop.2015.03.075_A-1-18, data:10.1016_j.indcrop.2015.03.075_A-1-19, data:10.1016_j.indcrop.2015.03.075_A-1-20, data:10.1016_j.indcrop.2015.03.075_A-1-21, data:10.1016_j.indcrop.2015.03.075_A-1-22, data:10.1016_j.indcrop.2015.03.075_A-1-23, data:10.1016_j.indcrop.2015.03.075_A-1-24, data:10.1016_j.indcrop.2015.03.075_A-1-25, data:10.1016_j.indcrop.2015.03.075_A-1-26, data:10.1016_j.indcrop.2015.03.075_A-1-27 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-1 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose nano-particles'^^xsd:string ;
# onner:offset '90'^^xsd:nonNegativeInteger ;
# onner:length '24'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-1 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-1 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-2 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'blue agave bagasse'^^xsd:string ;
# onner:offset '129'^^xsd:nonNegativeInteger ;
# onner:length '18'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-2 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-2 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-3 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'Cellulose nanofibers'^^xsd:string ;
# onner:offset '149'^^xsd:nonNegativeInteger ;
# onner:length '20'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-3 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-3 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-4 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'mechanical methods'^^xsd:string ;
# onner:offset '201'^^xsd:nonNegativeInteger ;
# onner:length '18'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-4 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-4 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-5 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose nanocrystals'^^xsd:string ;
# onner:offset '225'^^xsd:nonNegativeInteger ;
# onner:length '22'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-5 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-5 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-6 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'sulfuric acid'^^xsd:string ;
# onner:offset '266'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-6 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-6 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-7 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose extraction'^^xsd:string ;
# onner:offset '298'^^xsd:nonNegativeInteger ;
# onner:length '20'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-7 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-7 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-8 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'acid'^^xsd:string ;
# onner:offset '394'^^xsd:nonNegativeInteger ;
# onner:length '4'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-8 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-8 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-9 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'matrix'^^xsd:string ;
# onner:offset '403'^^xsd:nonNegativeInteger ;
# onner:length '6'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-9 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-9 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-10 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'fiber'^^xsd:string ;
# onner:offset '418'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-10 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-10 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-11 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulosic particles'^^xsd:string ;
# onner:offset '449'^^xsd:nonNegativeInteger ;
# onner:length '20'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-11 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-11 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-12 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'triethoxysilane silanized cellulose nanofibers'^^xsd:string ;
# onner:offset '525'^^xsd:nonNegativeInteger ;
# onner:length '46'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-12 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-12 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-13 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'dodecanoyl chloride esterified cellulose nanocrystals'^^xsd:string ;
# onner:offset '576'^^xsd:nonNegativeInteger ;
# onner:length '53'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-13 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-13 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-14 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'Non-cellulosic elimination'^^xsd:string ;
# onner:offset '632'^^xsd:nonNegativeInteger ;
# onner:length '26'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-14 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-14 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-15 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'infrared analysis'^^xsd:string ;
# onner:offset '718'^^xsd:nonNegativeInteger ;
# onner:length '17'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-15 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-15 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-16 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulosic species'^^xsd:string ;
# onner:offset '776'^^xsd:nonNegativeInteger ;
# onner:length '18'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-16 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-16 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-17 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'ester'^^xsd:string ;
# onner:offset '847'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-17 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-17 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-18 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose nanofibers'^^xsd:string ;
# onner:offset '901'^^xsd:nonNegativeInteger ;
# onner:length '20'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-18 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-18 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-19 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'nanocrystals'^^xsd:string ;
# onner:offset '926'^^xsd:nonNegativeInteger ;
# onner:length '12'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-19 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-19 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-20 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'atom-force microscopy'^^xsd:string ;
# onner:offset '958'^^xsd:nonNegativeInteger ;
# onner:length '21'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-20 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-20 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-21 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'crystallinity'^^xsd:string ;
# onner:offset '981'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-21 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-21 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-22 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'nano-'^^xsd:string ;
# onner:offset '998'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-22 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-22 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-23 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose'^^xsd:string ;
# onner:offset '1009'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-23 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-23 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-24 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'X-ray diffraction'^^xsd:string ;
# onner:offset '1068'^^xsd:nonNegativeInteger ;
# onner:length '17'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-24 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-24 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-25 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'stress-strain standard methods'^^xsd:string ;
# onner:offset '1163'^^xsd:nonNegativeInteger ;
# onner:length '30'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-25 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-25 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-26 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'strain'^^xsd:string ;
# onner:offset '1334'^^xsd:nonNegativeInteger ;
# onner:length '6'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-26 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-26 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_A-1-27 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'fracture'^^xsd:string ;
# onner:offset '1344'^^xsd:nonNegativeInteger ;
# onner:length '8'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_A-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-27 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_A-1-27 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# #========================= SECTION DIVIDER =========================#
#
# data:10.1016_j.indcrop.2015.03.075_1 rdf:type onner:Section ;
# onner:sectionTitle 'Introduction'^^xsd:string ;
# onner:sectionNumber '1'^^xsd:string ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:directlyContainsDocumentPart data:10.1016_j.indcrop.2015.03.075_1-1, data:10.1016_j.indcrop.2015.03.075_1-2, data:10.1016_j.indcrop.2015.03.075_1-3, data:10.1016_j.indcrop.2015.03.075_1-4, data:10.1016_j.indcrop.2015.03.075_1-5 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1 rdf:type onner:Paragraph ;
# onner:positionInParentDocumentPart '1'^^xsd:nonNegativeInteger ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:paragraphText 'Poly(lactic acid) or polylactide (PLA) is one of the most studied polymeric materials in the last two decades , even though until now, most of the PLA used in industry and scientific research has been obtained from petroleum, the feasibility of obtaining PLA from renewable resources makes it an interesting biopolymer for its study. Nevertheless, the slightly minor mechanical properties of PLA in respect to current used polymer mattresses , brings up the need to develop composite materials with determined characteristics in order to modify the behavior of PLA toward certain circumstances or applications.'^^xsd:string ;
# onner:directlyContainsLabeledTerm data:10.1016_j.indcrop.2015.03.075_1-1-1, data:10.1016_j.indcrop.2015.03.075_1-1-2, data:10.1016_j.indcrop.2015.03.075_1-1-3, data:10.1016_j.indcrop.2015.03.075_1-1-4, data:10.1016_j.indcrop.2015.03.075_1-1-5, data:10.1016_j.indcrop.2015.03.075_1-1-6, data:10.1016_j.indcrop.2015.03.075_1-1-7, data:10.1016_j.indcrop.2015.03.075_1-1-8, data:10.1016_j.indcrop.2015.03.075_1-1-9, data:10.1016_j.indcrop.2015.03.075_1-1-10, data:10.1016_j.indcrop.2015.03.075_1-1-11, data:10.1016_j.indcrop.2015.03.075_1-1-12 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-1 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'polylactide'^^xsd:string ;
# onner:offset '21'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-1 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-1 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-2 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '34'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-2 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-2 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-3 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '147'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-3 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-3 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-4 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'petroleum'^^xsd:string ;
# onner:offset '215'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-4 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-4 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-5 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'feasibility'^^xsd:string ;
# onner:offset '230'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-5 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-5 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-6 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '255'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-6 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-6 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-7 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'renewable'^^xsd:string ;
# onner:offset '264'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-7 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-7 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-8 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biopolymer'^^xsd:string ;
# onner:offset '308'^^xsd:nonNegativeInteger ;
# onner:length '10'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-8 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-8 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-9 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '392'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-9 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-9 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-10 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'polymer mattresses'^^xsd:string ;
# onner:offset '423'^^xsd:nonNegativeInteger ;
# onner:length '18'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-10 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-10 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-11 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'behavior'^^xsd:string ;
# onner:offset '549'^^xsd:nonNegativeInteger ;
# onner:length '8'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-11 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-11 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-1-12 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '561'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-12 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-1-12 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2 rdf:type onner:Paragraph ;
# onner:positionInParentDocumentPart '2'^^xsd:nonNegativeInteger ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_1-3 ;
# onner:paragraphText 'Recent works have highlighted the potential of lignocellulosic biomass as an alternative source of material for value added products, and biorefineries represent a suitable replace for conventional fossil refineries as the conversion of biomass into biofuels and biomaterials are becoming a more feasible alternative for traditional fuels and oil-derivate materials . Within the many possibilities of use that enclosures agricultural biomass, the obtention of bioplastics has increased attention from the scientific community, the possibility of reinforcing for biopolymers such as PLA to enhance its natural physical or chemical properties has boosted a wide series of researches. Among those who represent a most suitable option in elaborating biocomposites with this kind of plastics, are lignocellulosic materials, as they can be degraded or composted and present good behavior either as filler or as blend , the present study pretends to evaluate the performance of cellulose nanofibers and cellulose nanocrystals as fillers, either rough or after a surface modification with an hydrophobic additive.'^^xsd:string ;
# onner:directlyContainsLabeledTerm data:10.1016_j.indcrop.2015.03.075_1-2-1, data:10.1016_j.indcrop.2015.03.075_1-2-2, data:10.1016_j.indcrop.2015.03.075_1-2-3, data:10.1016_j.indcrop.2015.03.075_1-2-4, data:10.1016_j.indcrop.2015.03.075_1-2-5, data:10.1016_j.indcrop.2015.03.075_1-2-6, data:10.1016_j.indcrop.2015.03.075_1-2-7, data:10.1016_j.indcrop.2015.03.075_1-2-8, data:10.1016_j.indcrop.2015.03.075_1-2-9, data:10.1016_j.indcrop.2015.03.075_1-2-10, data:10.1016_j.indcrop.2015.03.075_1-2-11, data:10.1016_j.indcrop.2015.03.075_1-2-12, data:10.1016_j.indcrop.2015.03.075_1-2-13, data:10.1016_j.indcrop.2015.03.075_1-2-14, data:10.1016_j.indcrop.2015.03.075_1-2-15, data:10.1016_j.indcrop.2015.03.075_1-2-16, data:10.1016_j.indcrop.2015.03.075_1-2-17, data:10.1016_j.indcrop.2015.03.075_1-2-18, data:10.1016_j.indcrop.2015.03.075_1-2-19, data:10.1016_j.indcrop.2015.03.075_1-2-20, data:10.1016_j.indcrop.2015.03.075_1-2-21, data:10.1016_j.indcrop.2015.03.075_1-2-22 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-1 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'lignocellulosic biomass'^^xsd:string ;
# onner:offset '47'^^xsd:nonNegativeInteger ;
# onner:length '23'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-1 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-1 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-2 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biorefineries'^^xsd:string ;
# onner:offset '138'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-2 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-2 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-3 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'fossil'^^xsd:string ;
# onner:offset '198'^^xsd:nonNegativeInteger ;
# onner:length '6'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-3 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-3 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-4 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biomass'^^xsd:string ;
# onner:offset '237'^^xsd:nonNegativeInteger ;
# onner:length '7'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-4 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-4 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-5 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biofuels'^^xsd:string ;
# onner:offset '250'^^xsd:nonNegativeInteger ;
# onner:length '8'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-5 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-5 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-6 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'fuels'^^xsd:string ;
# onner:offset '333'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-6 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-6 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-7 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'oil-derivate materials'^^xsd:string ;
# onner:offset '343'^^xsd:nonNegativeInteger ;
# onner:length '22'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-7 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-7 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-8 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'enclosures agricultural biomass'^^xsd:string ;
# onner:offset '410'^^xsd:nonNegativeInteger ;
# onner:length '31'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-8 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-8 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-9 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'bioplastics'^^xsd:string ;
# onner:offset '460'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-9 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-9 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-10 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'community'^^xsd:string ;
# onner:offset '516'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-10 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-10 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-11 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biopolymers'^^xsd:string ;
# onner:offset '562'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-11 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-11 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-12 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '582'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-12 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-12 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-13 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'biocomposites'^^xsd:string ;
# onner:offset '746'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-13 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-13 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-14 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'plastics'^^xsd:string ;
# onner:offset '778'^^xsd:nonNegativeInteger ;
# onner:length '8'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-14 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-14 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-15 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'lignocellulosic materials'^^xsd:string ;
# onner:offset '792'^^xsd:nonNegativeInteger ;
# onner:length '25'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-15 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-15 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-16 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'composted'^^xsd:string ;
# onner:offset '846'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-16 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-16 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-17 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'blend'^^xsd:string ;
# onner:offset '905'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-17 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-17 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_4 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-18 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose nanofibers'^^xsd:string ;
# onner:offset '971'^^xsd:nonNegativeInteger ;
# onner:length '20'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-18 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-18 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-19 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose nanocrystals'^^xsd:string ;
# onner:offset '996'^^xsd:nonNegativeInteger ;
# onner:length '22'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-19 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-19 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-20 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'fillers'^^xsd:string ;
# onner:offset '1022'^^xsd:nonNegativeInteger ;
# onner:length '7'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-20 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-20 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-21 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'rough'^^xsd:string ;
# onner:offset '1038'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-21 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-21 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-2-22 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'hydrophobic'^^xsd:string ;
# onner:offset '1084'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-2 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-22 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-2-22 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_1-3 rdf:type onner:Paragraph ;
# onner:positionInParentDocumentPart '3'^^xsd:nonNegativeInteger ;
# onner:nextDocumentPart data:10.1016_j.indcrop.2015.03.075_1-4 ;
# onner:paragraphText 'One of the most used methods to obtain nanocrystalline particles is with sulfuric acid hydrolysis . In this process, sulfation occurs via condensation-esterification on the surface of cellulose nanocrystals, which displays a high surface area with a high amount of hydroxyl groups available that can react with the H <sub>2</sub> SO <sub>4</sub> molecule with the aid of another H <sub>2</sub> SO <sub>4</sub> molecule as condensation agent, thus forming a stable and well dispersed aqueous colloidal suspension as the result of the negative charge of the sulfated surface , this polar condition causes agglomeration during drying and aggregation in non-polar matrices because of the formation of additional hydrogen bonds between amorphous parts of the nanoparticles, making desirable a surface modification to optimize the fiber dispersion inside a polymeric matrix .'^^xsd:string ;
# onner:directlyContainsLabeledTerm data:10.1016_j.indcrop.2015.03.075_1-3-1, data:10.1016_j.indcrop.2015.03.075_1-3-2, data:10.1016_j.indcrop.2015.03.075_1-3-3, data:10.1016_j.indcrop.2015.03.075_1-3-4, data:10.1016_j.indcrop.2015.03.075_1-3-5, data:10.1016_j.indcrop.2015.03.075_1-3-6, data:10.1016_j.indcrop.2015.03.075_1-3-7, data:10.1016_j.indcrop.2015.03.075_1-3-8, data:10.1016_j.indcrop.2015.03.075_1-3-9, data:10.1016_j.indcrop.2015.03.075_1-3-10, data:10.1016_j.indcrop.2015.03.075_1-3-11, data:10.1016_j.indcrop.2015.03.075_1-3-12, data:10.1016_j.indcrop.2015.03.075_1-3-13, data:10.1016_j.indcrop.2015.03.075_1-3-14, data:10.1016_j.indcrop.2015.03.075_1-3-15 .
#
# data:10.1016_j.indcrop.2015.03.075_1-3-1 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'nanocrystalline particles'^^xsd:string ;
# onner:offset '39'^^xsd:nonNegativeInteger ;
# onner:length '25'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-3 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_1-3-1 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_1-3-1 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:06'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_1-3-2 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'sulfuric acid'^^xsd:string ;
# onner:offset '73'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_1-3 ;
# ...
# onner:offset '169'^^xsd:nonNegativeInteger ;
# onner:length '14'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-4 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-4 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-5 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'chemical and mechanical treatments'^^xsd:string ;
# onner:offset '195'^^xsd:nonNegativeInteger ;
# onner:length '34'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-5 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-5 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-6 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'feasibility'^^xsd:string ;
# onner:offset '373'^^xsd:nonNegativeInteger ;
# onner:length '11'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-6 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-6 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-7 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'the treatments'^^xsd:string ;
# onner:offset '388'^^xsd:nonNegativeInteger ;
# onner:length '14'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-7 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-7 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-8 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'Hydrophilic character'^^xsd:string ;
# onner:offset '448'^^xsd:nonNegativeInteger ;
# onner:length '21'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-8 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-8 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-9 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'cellulose'^^xsd:string ;
# onner:offset '473'^^xsd:nonNegativeInteger ;
# onner:length '9'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-9 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-9 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-10 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'nanofibers'^^xsd:string ;
# onner:offset '549'^^xsd:nonNegativeInteger ;
# onner:length '10'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-10 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-10 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-11 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'dodecanoyl chloride'^^xsd:string ;
# onner:offset '564'^^xsd:nonNegativeInteger ;
# onner:length '19'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-11 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-11 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-12 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'nanocrystals'^^xsd:string ;
# onner:offset '595'^^xsd:nonNegativeInteger ;
# onner:length '12'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-12 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-12 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-13 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'contact angle'^^xsd:string ;
# onner:offset '629'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-13 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-13 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-14 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'tensile tests'^^xsd:string ;
# onner:offset '647'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-14 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-14 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-15 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'suitable methods'^^xsd:string ;
# onner:offset '708'^^xsd:nonNegativeInteger ;
# onner:length '16'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-15 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-15 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-16 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'hydrophobicity'^^xsd:string ;
# onner:offset '762'^^xsd:nonNegativeInteger ;
# onner:length '14'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-16 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-16 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-17 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'non-polar covalent'^^xsd:string ;
# onner:offset '805'^^xsd:nonNegativeInteger ;
# onner:length '18'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-17 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-17 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_2 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-18 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'hydroxyl'^^xsd:string ;
# onner:offset '845'^^xsd:nonNegativeInteger ;
# onner:length '8'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-18 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-18 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-19 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'matrix'^^xsd:string ;
# onner:offset '912'^^xsd:nonNegativeInteger ;
# onner:length '6'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-19 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-19 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-20 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'water'^^xsd:string ;
# onner:offset '1004'^^xsd:nonNegativeInteger ;
# onner:length '5'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-20 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-20 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_1 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-21 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'uniaxial mechanical properties'^^xsd:string ;
# onner:offset '1090'^^xsd:nonNegativeInteger ;
# onner:length '30'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-21 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-21 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-22 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'anisotropy'^^xsd:string ;
# onner:offset '1168'^^xsd:nonNegativeInteger ;
# onner:length '10'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-22 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-22 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-23 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'matrix'^^xsd:string ;
# onner:offset '1204'^^xsd:nonNegativeInteger ;
# onner:length '6'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-23 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-23 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-24 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'crystallization'^^xsd:string ;
# onner:offset '1336'^^xsd:nonNegativeInteger ;
# onner:length '15'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-24 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-24 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_5 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-25 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'PLA'^^xsd:string ;
# onner:offset '1359'^^xsd:nonNegativeInteger ;
# onner:length '3'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-25 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-25 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_8 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-26 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'crystallinity'^^xsd:string ;
# onner:offset '1429'^^xsd:nonNegativeInteger ;
# onner:length '13'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-26 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-26 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_6 .
#
# data:10.1016_j.indcrop.2015.03.075_4-1-27 rdf:type onner:LabeledTerm ;
# onner:labeledTermText 'polymer'^^xsd:string ;
# onner:offset '1450'^^xsd:nonNegativeInteger ;
# onner:length '7'^^xsd:nonNegativeInteger ;
# onner:labeledTermDirectlyContainedBy data:10.1016_j.indcrop.2015.03.075_4-1 ;
# onner:hasLabeledTermStatus data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-27 .
#
# data:Candidate_10.1016_j.indcrop.2015.03.075_4-1-27 rdf:type onner:CandidateStatus ;
# onner:statusAssignmentDate '2024-03-17 00:34:08'^^xsd:dateTime ;
# onner:statusAssignedBy data:Cellulosic_NER_Model ;
# onner:hasLabeledTermLabel data:Label_3 .
#
# #========================= SECTION DIVIDER =========================#
#
# data:Label_2 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'MATERIAL'^^xsd:string .
#
# data:Label_6 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'PROPERTY'^^xsd:string .
#
# data:Label_3 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'MATERIAL_STRUCTURE'^^xsd:string .
#
# data:Label_5 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'PROCESS_OR_TECHNIQUE'^^xsd:string .
#
# data:Label_1 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'CHEMICAL'^^xsd:string .
#
# data:Label_8 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'ABBREVIATION'^^xsd:string .
#
# data:Label_4 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'APPLICATION'^^xsd:string .
#
# data:Label_7 rdf:type onner:Label ;
# onner:fromLabelingSchema data:Dev_Schema ;
# onner:labelText 'MEASUREMENT'^^xsd:string .
#
# data:Dev_Schema rdf:type onner:LabelingSchema ;
# onner:schemaName 'CelloGraph'^^xsd:string .
#
# data:Cellulosic_NER_Model rdf:type onner:NER_System ;
# onner:systemVersion '1.0'^^xsd:string .
#
# data:10.1016_j.indcrop.2015.03.075_EndOfDocument rdf:type onner:EndOfDocument .
